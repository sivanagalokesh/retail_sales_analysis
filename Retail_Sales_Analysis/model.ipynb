# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Data/realistic_linear_regression_dataset.csv")
df.head()
# Out:
#   ProductCategory Region CustomerSegment IsPromotionApplied  ProductionCost  \
# 0       Furniture   East     High Income                Yes      536.051521
# 1            Toys   West     High Income                 No      352.701361
# 2     Electronics  South     High Income                 No      618.989105
# 3       Furniture   West   Middle Income                Yes      339.959644
# 4       Furniture   West   Middle Income                Yes      477.951385
#
#    MarketingSpend  SeasonalDemandIndex  CompetitorPrice  CustomerRating  \
# 0      189.277811             1.159611       220.831351        4.035607
# 1      255.921497             1.545366       467.217175        4.106804
# 2      277.399353             1.671902       363.623261        4.021775
# 3      153.557699             1.408244       209.853621        4.148890
# 4      155.814478             2.177301       274.859950        4.913782
#
#    EconomicIndex  StoreCount  SalesRevenue
# ...

# %%
df.loc[df["SeasonalDemandIndex"] < 0, "SeasonalDemandIndex"] = 0

# %%
x = df.drop(columns =["SalesRevenue"])
y = df["SalesRevenue"]

# %%
x = pd.get_dummies(x, columns = ["ProductCategory", "Region", "CustomerSegment", "IsPromotionApplied"], drop_first = True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


x_scaler = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x_scaler, y, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

baseline_model = LinearRegression()
baseline_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

y_pred = baseline_model.predict(X_test)

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

r2, rmse, mae
# Out:
# (0.9287542699561677, 92.50963932188571, 73.43987172105177)

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

y_pred_ridge = ridge_model.predict(X_test)

r2_ridge = r2_score(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))
mae_ridge = mean_absolute_error(y_test, y_pred_ridge)

r2_ridge, rmse_ridge, mae_ridge
# Out:
# (0.9287492687874006, 92.51288617050159, 73.44505654653935)

# %%
from sklearn.linear_model import Lasso
lasso_model = Lasso(alpha=0.1, max_iter=10000)
lasso_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1, max_iter=10000)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

y_pred_lasso = lasso_model.predict(X_test)

r2_lasso = r2_score(y_test, y_pred_lasso)
rmse_lasso = np.sqrt(mean_squared_error(y_test, y_pred_lasso))
mae_lasso = mean_absolute_error(y_test, y_pred_lasso)

r2_lasso, rmse_lasso, mae_lasso
# Out:
# (0.9287859564711523, 92.48906521823164, 73.43101069055254)

# %%
import matplotlib.pyplot as plt
residuals = y_test - y_pred

plt.scatter(y_pred, residuals)
plt.axhline(0, color="red")
plt.xlabel("Predicted SalesRevenue")
plt.ylabel("Residuals")
plt.show()

# %%
insights = pd.DataFrame({
    "Feature": x.columns,
    "Impact": baseline_model.coef_
}).sort_values(by="Impact", key=abs, ascending=False)

# %%
insights
# Out:
#                           Feature      Impact
# 6                      StoreCount  286.330303
# 0                  ProductionCost  117.380268
# 4                  CustomerRating   98.923346
# 2             SeasonalDemandIndex   45.256206
# 3                 CompetitorPrice  -42.626134
# 1                  MarketingSpend   41.774738
# 5                   EconomicIndex    8.179362
# 9            ProductCategory_Toys   -6.615917
# 10                   Region_North    6.595504
# 8       ProductCategory_Furniture   -3.215967
# 14  CustomerSegment_Middle Income    2.813614
# 7     ProductCategory_Electronics   -1.855275
# 13     CustomerSegment_Low Income   -1.505446
# 12                    Region_West    0.928720
# 15         IsPromotionApplied_Yes   -0.919449
# 11                   Region_South    0.777845

# %%
import pickle

# Save model
with open("model.pkl", "wb") as f:
    pickle.dump(baseline_model, f)

# Save scaler
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# Save feature columns
with open("feature_columns.pkl", "wb") as f:
    pickle.dump(x.columns.tolist(), f)
